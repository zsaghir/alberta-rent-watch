# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

source_directory = PROJECT_ROOT / "src"

if str(source_directory) not in sys.path:
    sys.path.insert(0, str(source_directory))

raw_data_directory = (
    PROJECT_ROOT / "src" / "alberta_rent_watch" / "data" / "raw" / "cmhc"
)
# Out:
# Current directory: /Users/zainabsaghir/Documents/Builds/alberta-rent-watch/notebooks
# Project root: /Users/zainabsaghir/Documents/Builds/alberta-rent-watch
# Raw data directory: /Users/zainabsaghir/Documents/Builds/alberta-rent-watch/src/alberta_rent_watch/data/raw/cmhc
# Directory exists: True

# %%
raw_data_directory = (
    PROJECT_ROOT / "src/alberta_rent_watch/data/raw/cmhc"
)

rent = load_cmhc_data(raw_data_directory)
rent.head()
# Out:
# shape: (5, 4)
# ┌──────┬───────────────────┬──────────────┬──────────────┐
# │ year ┆ city              ┆ average_rent ┆ vacancy_rate │
# │ ---  ┆ ---               ┆ ---          ┆ ---          │
# │ i64  ┆ str               ┆ f64          ┆ f64          │
# ╞══════╪═══════════════════╪══════════════╪══════════════╡
# │ 2000 ┆ Edmonton, Alberta ┆ 603.0        ┆ 1.3          │
# │ 2001 ┆ Edmonton, Alberta ┆ 657.0        ┆ 0.9          │
# │ 2002 ┆ Edmonton, Alberta ┆ 710.0        ┆ 1.6          │
# │ 2003 ┆ Edmonton, Alberta ┆ 723.0        ┆ 3.5          │
# │ 2004 ┆ Edmonton, Alberta ┆ 729.0        ┆ 5.2          │
# └──────┴───────────────────┴──────────────┴──────────────┘
